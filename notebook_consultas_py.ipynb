# %%
import pandas as pd

# %%
path_leitura = "./intermunicipal_sc/ref/parquet/2019.parquet"

# %%
df = pd.read_parquet(path_leitura)

# %%
# df.info()

# %%
pd.set_option('display.max_rows', 1000)
prefixo = "679-1"
colunas = ["empresa", "prefixo", "ori_des_localidade_nome", "km"]
df[colunas][df.prefixo == prefixo].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_52621_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >empresa</th>
#       <th class="col_heading level0 col1" >prefixo</th>
#       <th class="col_heading level0 col2" >ori_des_localidade_nome</th>
#       <th class="col_heading level0 col3" >km</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52621_row0_col0" class="data row0 col0" >279-REAL TRANSPORTE E TURISMO SA </td>
#       <td id="T_52621_row0_col1" class="data row0 col1" >679-1</td>
#       <td id="T_52621_row0_col2" class="data row0 col2" >D CERQUEIRA-S JOSE DO CEDRO</td>
#       <td id="T_52621_row0_col3" class="data row0 col3" >33,89</td>
#     </tr>
#     <tr>
#       <td id="T_52621_row1_col0" class="data row1 col0" >279-REAL TRANSPORTE E TURISMO SA </td>
#       <td id="T_52621_row1_col1" class="data row1 col1" >679-1</td>
#       <td id="T_52621_row1_col2" class="data row1 col2" >D CERQUEIRA-S MIGUEL OESTE</td>
# ...
